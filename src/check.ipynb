# %%
import pandas as pd

# %%
df = pd.read_csv('../data/final/full_df.csv')

# %%
df[(df['year'] == '2020-01-01') & (df['chamber'] == 'senate')]
# Out:
#       Unnamed: 0        year chamber  district_number winner       DEM  \
# 1650        1650  2020-01-01  senate                1    REP   47248.0
# 1651        1651  2020-01-01  senate                2    REP   32870.0
# 1652        1652  2020-01-01  senate                3    DEM   45507.0
# 1653        1653  2020-01-01  senate                4    DEM   51384.0
# 1654        1654  2020-01-01  senate                5    DEM   51702.0
# 1655        1655  2020-01-01  senate                6    REP   25831.0
# 1656        1656  2020-01-01  senate                7    REP   36737.0
# 1657        1657  2020-01-01  senate                8    REP   48040.0
# 1658        1658  2020-01-01  senate                9    REP   61987.0
# 1659        1659  2020-01-01  senate               10    REP   30425.0
# 1660        1660  2020-01-01  senate               11    REP   50193.0
# 1661        1661  2020-01-01  senate               12    REP   36875.0
# ...
